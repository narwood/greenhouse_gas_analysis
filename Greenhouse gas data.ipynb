# %%
#import csv as DataFrame pandas object
import pandas as pd
df = pd.read_csv (r'C:\Users\nsarw\Downloads\Greenhouse_Gas.csv')
print(df.columns)
# Out:
# Index(['ObjectId2', 'Country', 'ISO2', 'ISO3', 'Indicator', 'Unit', 'Source',
#        'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor', 'Industry', 'Gas_Type',
#        'Scale', 'F2010', 'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016',
#        'F2017', 'F2018', 'F2019', 'F2020', 'F2021'],
#       dtype='object')

# %%
df_use = df[['Country', 'Industry', 'Gas_Type', 'F2010', 'F2011','F2012', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018', 'F2019', 'F2020', 'F2021']]
df_use.tail()
# Out:
#      Country                                           Industry  \
# 1048   World                         Transportation and Storage
# 1049   World  Water supply; sewerage, waste management and r...
# 1050   World  Water supply; sewerage, waste management and r...
# 1051   World  Water supply; sewerage, waste management and r...
# 1052   World  Water supply; sewerage, waste management and r...
#
#             Gas_Type        F2010        F2011        F2012        F2013  \
# 1048   Nitrous oxide    63.018148    64.393261    64.926048    65.861839
# 1049  Carbon dioxide   233.896826   231.071540   255.020810   258.297348
# 1050  Greenhouse gas  2749.793321  2795.280460  2868.285412  2898.376789
# 1051         Methane  2395.884042  2442.058042  2487.932118  2511.646109
# 1052   Nitrous oxide   120.012453   122.150877   125.332484   128.433332
#
#             F2014        F2015        F2016        F2017        F2018  \
# ...

# %%
df_use.groupby(["Industry","Gas_Type"], as_index=False)["F2017"].sum()
# Out:
#                                              Industry           Gas_Type  \
# 0                   Agriculture, Forestry and Fishing     Carbon dioxide
# 1                   Agriculture, Forestry and Fishing     Greenhouse gas
# 2                   Agriculture, Forestry and Fishing            Methane
# 3                   Agriculture, Forestry and Fishing      Nitrous oxide
# 4                                        Construction     Carbon dioxide
# 5                                        Construction     Greenhouse gas
# 6                                        Construction            Methane
# 7                                        Construction      Nitrous oxide
# 8   Electricity, Gas, Steam and Air Conditioning S...     Carbon dioxide
# 9   Electricity, Gas, Steam and Air Conditioning S...     Greenhouse gas
# 10  Electricity, Gas, Steam and Air Conditioning S...            Methane
# 11  Electricity, Gas, Steam and Air Conditioning S...      Nitrous oxide
# ...

# %%
df_africa = df_use[df_use['Country'].isin(['Africa', 'Asia', 'Europe', 'Oceania', 'Americas'])];
df_africa
# Out:
#      Country                                           Industry  \
# 45    Africa                  Agriculture, Forestry and Fishing
# 46    Africa                  Agriculture, Forestry and Fishing
# 47    Africa                  Agriculture, Forestry and Fishing
# 48    Africa                  Agriculture, Forestry and Fishing
# 49    Africa                                       Construction
# ..       ...                                                ...
# 747  Oceania                         Transportation and Storage
# 748  Oceania  Water supply; sewerage, waste management and r...
# 749  Oceania  Water supply; sewerage, waste management and r...
# 750  Oceania  Water supply; sewerage, waste management and r...
# 751  Oceania  Water supply; sewerage, waste management and r...
#
#            Gas_Type       F2010       F2011       F2012       F2013  \
# 45   Carbon dioxide    5.483346    5.561609    6.161359    6.640417
# ...
