# %%
import pandas as pd
import numpy as np

# GIS

# Country, Industry, Gas_Type

# %%
df = pd.read_csv("Annual_Greenhouse_Gas_(GHG)_Air_Emissions_Accounts.csv")
df_use = df[['Country', 'Industry', 'Gas_Type', 'F2010', 'F2011','F2012', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018', 'F2019', 'F2020', 'F2021']]
df_use
# Out:
#                  Country                                           Industry  \
# 0     Advanced Economies                  Agriculture, Forestry and Fishing
# 1     Advanced Economies                  Agriculture, Forestry and Fishing
# 2     Advanced Economies                  Agriculture, Forestry and Fishing
# 3     Advanced Economies                  Agriculture, Forestry and Fishing
# 4     Advanced Economies                                       Construction
# ...                  ...                                                ...
# 1048               World                         Transportation and Storage
# 1049               World  Water supply; sewerage, waste management and r...
# 1050               World  Water supply; sewerage, waste management and r...
# 1051               World  Water supply; sewerage, waste management and r...
# 1052               World  Water supply; sewerage, waste management and r...
#
# ...

# %%
array = df_use.to_numpy()

# 0=Country, 1=Industry, 2=Gas_Type, 3=F2010, ... , 14=F2021

countries = df_use.Country.unique()
industries = df_use.Industry.unique()
gas_types = df_use.Gas_Type.unique()

countries_totals = dict(zip(countries, np.zeros(len(countries), dtype=int)))
industries_totals = dict(zip(industries, np.zeros(len(industries), dtype=int)))
gastypes_totals = dict(zip(gas_types, np.zeros(len(gas_types), dtype=int)))

for obs in array:
    obs_total = sum(obs[3:])
    obs_country = obs[0]
    obs_industry = obs[1]
    obs_gastype = obs[2]
    countries_totals[obs_country] += obs_total
    industries_totals[obs_industry] += obs_total
    gastypes_totals[obs_gastype] += obs_total
    
print(countries_totals)
print()
print(industries_totals)
print()
print(gastypes_totals)
print()
# Out:
# {'Advanced Economies': 678069.708119104, 'Africa': 142101.623154143, 'Americas': 512229.191508563, 'Asia': 1288321.9230567643, 'Australia and New Zealand': 31691.859067813, 'Central Asia': 31242.76675137301, 'Eastern Asia': 764135.6803254458, 'Eastern Europe': 158473.51169946996, 'Emerging and Developing Economies': 1641254.0208318643, 'Europe': 344979.13218320697, 'G20': 1833711.1346378212, 'G7': 517664.7131308409, 'Latin America and the Caribbean': 169586.260894189, 'Northern Africa': 45252.014393934, 'Northern America': 342649.7495755451, 'Northern Europe': 47739.531071051, 'Oceania': 31691.859067813, 'South-eastern Asia': 125368.39560463799, 'Southern Asia': 244221.34695211294, 'Southern Europe': 50481.17235493699, 'Sub-Saharan Africa': 96829.05077542702, 'Western Asia': 123503.20795441899, 'Western Europe': 88284.403826749, 'World': 2319323.72896718}
#
# ...
